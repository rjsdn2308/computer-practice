# %% [markdown]
# # 예제 1 : 우편번호 인식기 v2
# - 1.1. LeNet 재현
# - 1.2. 우편번호 인식기 v2 구현

# %% [markdown]
# ## 1.1 : LeNet 재현

# %% [markdown]
# ### 라이브러리 불러오기

# %%
import numpy as np
import tensorflow as tf
import tensorflow.keras.datasets as ds # keras 라는 api를 사용

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D,MaxPooling2D,Flatten,Dropout,Dense,Input
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# ### 데이터 준비

# %%
(x_train,y_train),(x_test,y_test)=ds.mnist.load_data()
x_train.shape # 훈련 데이터는 6만 가로 x 세로는 28 by 28
# Out:
# (60000, 28, 28)

# %%
x_train=x_train.reshape(60000,28,28,1)
x_test=x_test.reshape(10000,28,28,1)
x_train.shape
# Out:
# (60000, 28, 28, 1)

# %%
x_train=x_train.astype(np.float32)/255.0
x_test=x_test.astype(np.float32)/255.0 # 데이터 전처리를 정의해줌

# %%
y_train=tf.keras.utils.to_categorical(y_train,10)
y_test=tf.keras.utils.to_categorical(y_test,10) # 데이터 전처리를 해줌

# %% [markdown]
# ### 모델 정의

# %%
cnn=Sequential()
input = Input(shape=(28,28,1)) # 1은 이미지 차원을 말합니다. functional api로 사용 
cnn.add(input)
cnn.add(Conv2D(6,(5,5),padding='same',activation='relu')) # 6은 필터의 개수, (5,5)는 커널 
cnn.add(MaxPooling2D(pool_size=(2,2),strides=2))
cnn.add(Conv2D(16,(5,5),padding='valid',activation='relu'))
cnn.add(MaxPooling2D(pool_size=(2,2),strides=2))
cnn.add(Conv2D(120,(5,5),padding='valid',activation='relu'))
cnn.add(Flatten())
cnn.add(Dense(units=84,activation='relu'))
cnn.add(Dense(units=10,activation='softmax'))

# %% [markdown]
# ### 학습 및 평가

# %%
cnn.compile(loss='categorical_crossentropy',optimizer=Adam(learning_rate=0.001),metrics=['accuracy'])
cnn.fit(x_train,y_train,batch_size=128,epochs=30,validation_data=(x_test,y_test),verbose=2)
# Out:
# Epoch 1/30
# 469/469 - 6s - 12ms/step - accuracy: 0.9033 - loss: 0.3210 - val_accuracy: 0.9726 - val_loss: 0.0878
# Epoch 2/30
# 469/469 - 4s - 8ms/step - accuracy: 0.9739 - loss: 0.0860 - val_accuracy: 0.9832 - val_loss: 0.0507
# Epoch 3/30
# 469/469 - 5s - 10ms/step - accuracy: 0.9814 - loss: 0.0596 - val_accuracy: 0.9864 - val_loss: 0.0413
# Epoch 4/30
# 469/469 - 4s - 8ms/step - accuracy: 0.9855 - loss: 0.0468 - val_accuracy: 0.9870 - val_loss: 0.0393
# Epoch 5/30
# 469/469 - 3s - 7ms/step - accuracy: 0.9883 - loss: 0.0387 - val_accuracy: 0.9812 - val_loss: 0.0515
# Epoch 6/30
# 469/469 - 3s - 7ms/step - accuracy: 0.9898 - loss: 0.0325 - val_accuracy: 0.9873 - val_loss: 0.0339
# Epoch 7/30
# 469/469 - 4s - 8ms/step - accuracy: 0.9908 - loss: 0.0290 - val_accuracy: 0.9862 - val_loss: 0.0408
# Epoch 8/30
# 469/469 - 3s - 7ms/step - accuracy: 0.9920 - loss: 0.0238 - val_accuracy: 0.9895 - val_loss: 0.0318
# Epoch 9/30
# 469/469 - 3s - 7ms/step - accuracy: 0.9928 - loss: 0.0210 - val_accuracy: 0.9905 - val_loss: 0.0294
# Epoch 10/30
# 469/469 - 4s - 9ms/step - accuracy: 0.9941 - loss: 0.0184 - val_accuracy: 0.9917 - val_loss: 0.0271
# Epoch 11/30
# 469/469 - 3s - 7ms/step - accuracy: 0.9937 - loss: 0.0181 - val_accuracy: 0.9906 - val_loss: 0.0294
# Epoch 12/30
# 469/469 - 4s - 8ms/step - accuracy: 0.9956 - loss: 0.0136 - val_accuracy: 0.9904 - val_loss: 0.0306
# Epoch 13/30
# 469/469 - 4s - 8ms/step - accuracy: 0.9956 - loss: 0.0130 - val_accuracy: 0.9910 - val_loss: 0.0271
# Epoch 14/30
# 469/469 - 4s - 8ms/step - accuracy: 0.9962 - loss: 0.0116 - val_accuracy: 0.9917 - val_loss: 0.0294
# Epoch 15/30
# 469/469 - 3s - 7ms/step - accuracy: 0.9961 - loss: 0.0119 - val_accuracy: 0.9894 - val_loss: 0.0348
# Epoch 16/30
# 469/469 - 4s - 8ms/step - accuracy: 0.9971 - loss: 0.0096 - val_accuracy: 0.9903 - val_loss: 0.0302
# Epoch 17/30
# 469/469 - 4s - 8ms/step - accuracy: 0.9971 - loss: 0.0088 - val_accuracy: 0.9888 - val_loss: 0.0409
# Epoch 18/30
# 469/469 - 4s - 8ms/step - accuracy: 0.9977 - loss: 0.0075 - val_accuracy: 0.9878 - val_loss: 0.0489
# Epoch 19/30
# 469/469 - 4s - 8ms/step - accuracy: 0.9976 - loss: 0.0071 - val_accuracy: 0.9903 - val_loss: 0.0369
# Epoch 20/30
# 469/469 - 4s - 8ms/step - accuracy: 0.9971 - loss: 0.0080 - val_accuracy: 0.9902 - val_loss: 0.0382
# Epoch 21/30
# 469/469 - 4s - 8ms/step - accuracy: 0.9974 - loss: 0.0079 - val_accuracy: 0.9895 - val_loss: 0.0418
# Epoch 22/30
# 469/469 - 4s - 8ms/step - accuracy: 0.9984 - loss: 0.0045 - val_accuracy: 0.9891 - val_loss: 0.0449
# Epoch 23/30
# 469/469 - 4s - 8ms/step - accuracy: 0.9977 - loss: 0.0065 - val_accuracy: 0.9906 - val_loss: 0.0400
# Epoch 24/30
# 469/469 - 4s - 8ms/step - accuracy: 0.9981 - loss: 0.0055 - val_accuracy: 0.9913 - val_loss: 0.0398
# Epoch 25/30
# 469/469 - 4s - 8ms/step - accuracy: 0.9980 - loss: 0.0053 - val_accuracy: 0.9870 - val_loss: 0.0628
# Epoch 26/30
# 469/469 - 4s - 8ms/step - accuracy: 0.9983 - loss: 0.0049 - val_accuracy: 0.9908 - val_loss: 0.0406
# Epoch 27/30
# 469/469 - 4s - 8ms/step - accuracy: 0.9984 - loss: 0.0049 - val_accuracy: 0.9905 - val_loss: 0.0381
# Epoch 28/30
# 469/469 - 4s - 8ms/step - accuracy: 0.9984 - loss: 0.0050 - val_accuracy: 0.9908 - val_loss: 0.0450
# Epoch 29/30
# 469/469 - 4s - 8ms/step - accuracy: 0.9985 - loss: 0.0043 - val_accuracy: 0.9908 - val_loss: 0.0438
# Epoch 30/30
# 469/469 - 4s - 9ms/step - accuracy: 0.9985 - loss: 0.0047 - val_accuracy: 0.9908 - val_loss: 0.0429

# %%
res=cnn.evaluate(x_test,y_test,verbose=0)
print('정확도=',res[1]*100)
# Out:
# 정확도= 99.08000230789185

# %% [markdown]
# ### 모델 저장

# %%
cnn.save('cnn_v2.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# ## 1.2. : 우편번호 인식기 v2 구현

# %% [markdown]
# ### 라이브러리 불러오기

# %%
## 라이브러리 불러오기
import numpy as np
import tensorflow as tf
import cv2 as cv
import matplotlib.pyplot as plt

# %% [markdown]
# ### 저장한 모델 불러오기
#
# - `LeNet` 재현 실습을 통해 저장한 모델 불러오기
# - MNIST 데이터셋으로 학습된 손글씨 숫자 인식 모델

# %%
model = tf.keras.models.load_model('cnn_v2.h5')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %% [markdown]
# ### 초기화 함수 정의
# - 우편번호 작성 화면 초기화
# - 5개의 숫자를 작성할 수 있는 영역 생성, 안내 텍스트 표시

# %%
def reset():
    global img
    img = np.ones((200, 520, 3), dtype=np.uint8) * 255
    for i in range(5):
        cv.rectangle(img, (10 + i * 100, 50), (10 + (i + 1) * 100, 150), (0, 0, 255))
    cv.putText(img, 'e:erase s:show r:recognition q:quit', (10, 40), cv.FONT_HERSHEY_SIMPLEX, 0.8, (255, 0, 0), 1)

# %% [markdown]
# ### 숫자 추출 함수 정의
# - 작성된 숫자를 추출하여 모델이 처리할 수 있는 형태로 변환
# - 각 숫자는 28x28 크기로 리사이즈, 흑백으로 변환

# %%
def grab_numerals():
    numerals = []
    for i in range(5):
        roi = img[51:149, 11 + i * 100:9 + (i + 1) * 100, 0]
        roi = 255 - cv.resize(roi, (28, 28), interpolation=cv.INTER_CUBIC)
        numerals.append(roi)
    numerals = np.array(numerals) 
    return numerals

# %% [markdown]
# ### 숫자 시각화 함수 정의
#
# - 추출된 숫자를 화면에 표시
# - 사용자가 작성한 숫자 확인 가능

# %%
def show():
    numerals = grab_numerals()
    plt.figure(figsize=(25, 5))
    for i in range(5):
        plt.subplot(1, 5, i + 1)
        plt.imshow(numerals[i], cmap='gray')
        plt.xticks([]); plt.yticks([])
    plt.show()

# %% [markdown]
# ### 숫자 인식 함수 정의
# - 추출된 숫자를 모델에 입력하여 예측
# - 예측된 숫자는 화면에 표시되고 소리를 재생함

# %%
def recognition():
    numerals = grab_numerals()
    numerals = numerals.reshape(5, 28, 28) # 지난 실습 7-7.ipynb (5, 784)에서 (5, 28, 28) 로 변경
    numerals = numerals.astype(np.float32) / 255.0
    res = model.predict(numerals)  # 신경망 모델로 예측
    class_id = np.argmax(res, axis=1)
    for i in range(5):
        cv.putText(img, str(class_id[i]), (50 + i * 100, 180), cv.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 0), 1)
    # winsound.Beep(1000, 500)

# %% [markdown]
# ### 마우스 이벤트 처리
#
# - 왼쪽 버튼을 클릭하거나 드래그하면 숫자를 작성할 수 있음

# %%
BrushSiz = 4
LColor = (0, 0, 0)

def writing(event, x, y, flags, param):
    if event == cv.EVENT_LBUTTONDOWN:
        cv.circle(img, (x, y), BrushSiz, LColor, -1)
    elif event == cv.EVENT_MOUSEMOVE and flags == cv.EVENT_FLAG_LBUTTON:
        cv.circle(img, (x, y), BrushSiz, LColor, -1)

# %% [markdown]
# ### 메인 루프
#
# - 사용자는 'e', 's', 'r', 'q' 키를 사용하여 초기화, 시각화, 인식, 종료를 수행함

# %%
reset()
cv.namedWindow('Writing')
cv.setMouseCallback('Writing', writing)

while True:
    cv.imshow('Writing', img)
    key = cv.waitKey(1)
    if key == ord('e'):
        reset()
    elif key == ord('s'):
        show()
    elif key == ord('r'):
        recognition()
    elif key == ord('q'):
        break

cv.destroyAllWindows()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step

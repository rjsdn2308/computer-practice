# %% [markdown]
# # 깊은 다층 퍼셉트론으로 MNIST 손글씨 인식
# - 데이터 전처리, 모델 정의, 학습, 평가, 시각화 진행

# %% [markdown]
# ## 라이브러리 불러오기

# %%
import numpy as np
import tensorflow as tf
import tensorflow.keras.datasets as ds
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Input
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt

# %%
ds.mnist
# Out:
# <module 'keras.datasets.mnist' from 'c:\\Users\\gunwo\\anaconda3\\envs\\TEST\\Lib\\site-packages\\keras\\datasets\\mnist\\__init__.py'>

# %% [markdown]
# ## 데이터 전처리
#
# - MNIST 데이터셋 불러오기 및 전처리
# - 데이터는 28x28 흑백 이미지를 1차원 벡터(784차원)로 변환
# - 픽셀 값을 [0, 1] 범위로 정규화
# - 레이블을 원-핫 인코딩으로 변환

# %%
(x_train, y_train), (x_test, y_test) = ds.mnist.load_data()

# 데이터 정규화 및 1차원 벡터로 변환
x_train = x_train.reshape(60000, 784).astype(np.float32) / 255.0
x_test = x_test.reshape(10000, 784).astype(np.float32) / 255.0

# 레이블을 원-핫 인코딩으로 변환
y_train = tf.keras.utils.to_categorical(y_train, 10)
y_test = tf.keras.utils.to_categorical(y_test, 10)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
dmlp = Sequential()
dmlp.add(Input(shape=(784,)))
dmlp.add(Dense(units=1024, activation='relu'))
dmlp.add(Dropout(0.4))
dmlp.add(Dense(units=512, activation='relu'))
dmlp.add(Dropout(0.4))
dmlp.add(Dense(units=512, activation='relu'))
dmlp.add(Dropout(0.4))
dmlp.add(Dense(units=10, activation='softmax'))

# %% [markdown]
# ## 모델 컴파일 및 학습
#
# - 손실 함수: categorical_crossentropy (다중 클래스 분류)
# - 옵티마이저: Adam
# - 평가 지표: accuracy
# - 배치 크기 : 128, 에포크 : 50 으로 학습 진행

# %%
dmlp.compile(loss='categorical_crossentropy', optimizer=Adam(learning_rate=0.01), metrics=['accuracy'])
hist = dmlp.fit(x_train, y_train, batch_size=128, epochs=30, validation_data=(x_test, y_test), verbose=2)
# Out:
# Epoch 1/30
# 469/469 - 5s - 10ms/step - accuracy: 0.8425 - loss: 0.6066 - val_accuracy: 0.9302 - val_loss: 0.2811
# Epoch 2/30
# 469/469 - 4s - 8ms/step - accuracy: 0.8657 - loss: 0.5757 - val_accuracy: 0.9255 - val_loss: 0.3310
# Epoch 3/30
# 469/469 - 4s - 8ms/step - accuracy: 0.8607 - loss: 0.6082 - val_accuracy: 0.9354 - val_loss: 0.3136
# Epoch 4/30
# 469/469 - 4s - 8ms/step - accuracy: 0.8676 - loss: 0.5954 - val_accuracy: 0.9321 - val_loss: 0.2990
# Epoch 5/30
# 469/469 - 4s - 8ms/step - accuracy: 0.8644 - loss: 0.6031 - val_accuracy: 0.9262 - val_loss: 0.3962
# Epoch 6/30
# 469/469 - 4s - 8ms/step - accuracy: 0.8614 - loss: 0.6159 - val_accuracy: 0.9240 - val_loss: 0.3227
# Epoch 7/30
# 469/469 - 4s - 8ms/step - accuracy: 0.8560 - loss: 0.6432 - val_accuracy: 0.9323 - val_loss: 0.3403
# Epoch 8/30
# 469/469 - 4s - 8ms/step - accuracy: 0.8592 - loss: 0.6157 - val_accuracy: 0.9348 - val_loss: 0.3392
# Epoch 9/30
# 469/469 - 4s - 9ms/step - accuracy: 0.8708 - loss: 0.5705 - val_accuracy: 0.9336 - val_loss: 0.3622
# Epoch 10/30
# 469/469 - 4s - 8ms/step - accuracy: 0.8640 - loss: 0.6036 - val_accuracy: 0.9384 - val_loss: 0.3362
# Epoch 11/30
# 469/469 - 4s - 8ms/step - accuracy: 0.8691 - loss: 0.5593 - val_accuracy: 0.9340 - val_loss: 0.3480
# Epoch 12/30
# 469/469 - 4s - 8ms/step - accuracy: 0.8627 - loss: 0.5910 - val_accuracy: 0.9278 - val_loss: 0.3618
# Epoch 13/30
# 469/469 - 4s - 8ms/step - accuracy: 0.8620 - loss: 0.6334 - val_accuracy: 0.9332 - val_loss: 0.3274
# Epoch 14/30
# 469/469 - 4s - 8ms/step - accuracy: 0.8597 - loss: 0.6027 - val_accuracy: 0.9302 - val_loss: 0.3881
# Epoch 15/30
# 469/469 - 4s - 8ms/step - accuracy: 0.8597 - loss: 0.5973 - val_accuracy: 0.9285 - val_loss: 0.3624
# Epoch 16/30
# 469/469 - 4s - 8ms/step - accuracy: 0.8641 - loss: 0.5847 - val_accuracy: 0.9380 - val_loss: 0.3778
# Epoch 17/30
# 469/469 - 4s - 8ms/step - accuracy: 0.8612 - loss: 0.5821 - val_accuracy: 0.9369 - val_loss: 0.3644
# Epoch 18/30
# 469/469 - 4s - 9ms/step - accuracy: 0.8627 - loss: 0.6170 - val_accuracy: 0.9348 - val_loss: 0.4112
# Epoch 19/30
# 469/469 - 5s - 10ms/step - accuracy: 0.8634 - loss: 0.5765 - val_accuracy: 0.9398 - val_loss: 0.4550
# Epoch 20/30
# 469/469 - 5s - 10ms/step - accuracy: 0.8620 - loss: 0.5634 - val_accuracy: 0.9368 - val_loss: 0.3711
# Epoch 21/30
# 469/469 - 4s - 9ms/step - accuracy: 0.8614 - loss: 0.5699 - val_accuracy: 0.9416 - val_loss: 0.3295
# Epoch 22/30
# 469/469 - 4s - 9ms/step - accuracy: 0.8634 - loss: 0.5779 - val_accuracy: 0.9317 - val_loss: 0.3352
# Epoch 23/30
# 469/469 - 5s - 10ms/step - accuracy: 0.8641 - loss: 0.5739 - val_accuracy: 0.9286 - val_loss: 0.3952
# Epoch 24/30
# 469/469 - 5s - 10ms/step - accuracy: 0.8664 - loss: 0.5691 - val_accuracy: 0.9356 - val_loss: 0.3051
# Epoch 25/30
# 469/469 - 4s - 9ms/step - accuracy: 0.8643 - loss: 0.5517 - val_accuracy: 0.9411 - val_loss: 0.3594
# Epoch 26/30
# 469/469 - 4s - 9ms/step - accuracy: 0.8640 - loss: 0.5797 - val_accuracy: 0.9356 - val_loss: 0.4337
# Epoch 27/30
# 469/469 - 4s - 9ms/step - accuracy: 0.8629 - loss: 0.5822 - val_accuracy: 0.9242 - val_loss: 0.4244
# Epoch 28/30
# 469/469 - 5s - 10ms/step - accuracy: 0.8554 - loss: 0.6253 - val_accuracy: 0.9298 - val_loss: 0.5469
# Epoch 29/30
# 469/469 - 4s - 9ms/step - accuracy: 0.8626 - loss: 0.5943 - val_accuracy: 0.9377 - val_loss: 0.4601
# Epoch 30/30
# 469/469 - 5s - 10ms/step - accuracy: 0.8502 - loss: 0.6148 - val_accuracy: 0.9235 - val_loss: 0.4891

# %% [markdown]
# ## 모델 평가

# %%
accuracy = dmlp.evaluate(x_test, y_test, verbose=0)[1] * 100
print(f'정확률 = {accuracy:.2f}%')
# Out:
# 정확률 = 92.35%

# %% [markdown]
# ## 모델 저장

# %%
dmlp.save('dmlp_trained.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# ## 모델 시각화

# %%
# 정확도 그래프
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Accuracy graph')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend(['train', 'test'])
plt.grid()
plt.show()

# 손실 그래프
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Loss graph')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend(['train', 'test'])
plt.grid()
plt.show()
